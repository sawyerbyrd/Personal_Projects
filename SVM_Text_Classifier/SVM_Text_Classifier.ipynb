# %% [markdown]
# Sawyer Byrd
#
# HW1

# %%
#imports 
from pathlib import Path
import numpy as np
import pandas as pd
import re
import math
from collections import Counter
from qpsolvers import solve_qp
from cvxopt import matrix, solvers

# %%
# setting directory
directory = Path('/home/sawbyrd/CMSC422/HW2/20_newsgroups')

# %%
# index of label in list will corespond to label number.
# e.g. 'comp.graphics' is at index 1 so its label number will be 1.

labels = []

for file_path in directory.iterdir(): 
   labels.append(file_path.name)

print(labels)
# Out:
# ['comp.os.ms-windows.misc', 'soc.religion.christian', 'sci.med', 'talk.politics.misc', 'comp.windows.x', 'sci.space', 'rec.sport.hockey', 'sci.electronics', 'misc.forsale', 'talk.politics.mideast', 'comp.sys.ibm.pc.hardware', 'talk.politics.guns', 'talk.religion.misc', 'alt.atheism', 'rec.autos', 'sci.crypt', 'rec.sport.baseball', 'rec.motorcycles', 'comp.graphics', 'comp.sys.mac.hardware']

# %%
def remove_first_4(file_path): 
    file = file_path.open('r', errors='ignore')
    lines = file.readlines()
    return lines[4:]

# %%
# returns the cleaned, lowercase, tokenized text.

def tokenize(text):
    text = text.lower()
    # collects only alphanumeric and spaces 
    cleaned = re.sub(r'[^a-z\s]', ' ', text)
    # sorts though for words of length >= 2
    tokens = re.findall(r'\b[a-z]{2,}\b', cleaned)
    return tokens

# %%
# each row has: col1 -> doc contents ; col2 -> label

# list that will be used to create dataframe
docs = []

# iterating through class files
for label_path in directory.iterdir():
    # iterating through each doc 
    for file_path in label_path.iterdir():
        if file_path.is_file():
            # removing the first 4 lines, making it into one string and tokenizing it
            doc_content = remove_first_4(file_path)
            doc_content = tokenize(''.join(doc_content))
            docs.append({
                'Contents': doc_content,
                'Label': labels.index(label_path.name)
            })

all_docs = pd.DataFrame(docs)

# %%
print(all_docs)
# Out:
#                                                 Contents  Label
# 0      [nntp, posting, host, alexandre, dumas, ics, u...      0
# 1      [message, id, apr, nlm, nih, gov, organization...      0
# 2      [date, may, gmt, organization, case, western, ...      0
# 3      [date, thu, may, gmt, organization, southweste...      0
# 4      [message, id, apr, csc, canberra, edu, au, sen...      0
# ...                                                  ...    ...
# 19992  [subject, cannot, move, data, fast, enough, me...     19
# 19993  [date, apr, gmt, organization, inst, thermodyn...     19
# 19994  [message, id, mny, imag, fr, sender, news, ima...     19
# 19995  [message, id, mm, news, cso, uiuc, edu, date, ...     19
# 19996  [date, apr, organization, stanford, university...     19
#
# [19997 rows x 2 columns]

# %%
def train_test_split(data):   
    train_temp = []
    test_temp = []
    # half of the docs from each class in train and half in test
    for label in range(20): 
        class_df = data[data['Label'] == label]
        # shuffling the class set before spliting
        class_df = class_df.sample(frac=1, random_state=37).reset_index(drop=True)
        train_temp.append(class_df[:500])
        test_temp.append(class_df[500:])

    # concat all dfs for train and test into one df each
    # shuffling test for randomness
    train = pd.concat(train_temp).reset_index(drop=True)
    train = train.sample(frac=1, random_state=37).reset_index(drop=True)
    test = pd.concat(test_temp).reset_index(drop=True)
    test = test.sample(frac=1, random_state=37).reset_index(drop=True)
    
    # Adding Y-Hat col for predictions
    train['SVM Y-Hat'] = np.nan
    train['Poly Y-Hat'] = np.nan
    test['SVM Y-Hat'] = np.nan
    test['Poly Y-Hat'] = np.nan
    
    train['Tf'] = [Counter() for _ in range(len(train))]
    test['Tf'] = [Counter() for _ in range(len(test))]

    return train, test

train, test = train_test_split(all_docs)
train
# Out:
#                                                Contents  Label  SVM Y-Hat  \
# 0     [date, apr, gmt, organization, computer, scien...     16        NaN
# 1     [date, apr, gmt, organization, stratus, comput...      2        NaN
# 2     [message, id, xp, brunel, ac, uk, organization...      5        NaN
# 3     [message, id, apr, mprgate, mpr, ca, sender, j...      4        NaN
# 4     [from, srgxnbs, grace, cri, nz, date, mon, apr...      7        NaN
# ...                                                 ...    ...        ...
# 9995  [organization, at, distribution, usa, date, fr...      8        NaN
# 9996  [message, id, may, athos, rutgers, edu, date, ...      1        NaN
# 9997  [subject, imagine, for, pc, message, id, kruzi...     18        NaN
# 9998  [message, id, apr, ultb, isc, rit, edu, sender...      8        NaN
# 9999  [subject, re, new, study, out, on, gay, percen...      3        NaN
#
#       Poly Y-Hat  Tf
# 0            NaN  {}
# 1            NaN  {}
# 2            NaN  {}
# 3            NaN  {}
# 4            NaN  {}
# ...          ...  ..
# 9995         NaN  {}
# 9996         NaN  {}
# 9997         NaN  {}
# 9998         NaN  {}
# 9999         NaN  {}
#
# [10000 rows x 5 columns]

# %% [markdown]
# Updates Document Term Frequency with vocab

# %% [markdown]
# Creating vocabulary while keeping track of tf and df
#
# Also updates data with new vocab

# %%
def calc_tf(data, vocab):
    for i, row in data.iterrows():
        cont = row['Contents']
        cont = [word for word in cont if word in vocab]
        data.at[i, 'Tf'] = Counter(cont)

# %%
def create_vocab(data):
    vocab = Counter(word for doc in data['Contents'] for word in doc)
    stop_lst = {word for word, _ in vocab.most_common(300)}
    
    vocab = Counter({word: freq for word, freq in vocab.items() if word not in stop_lst})
    vocab = Counter({word: freq for word, freq in vocab.most_common(500)})
    
    calc_tf(data, vocab)
    
    return vocab

vocab = create_vocab(train)

# %% [markdown]
# Defining IDF Weight function

# %%
# this is the inverse document frequency (idf) function

def idf(doc_f, n_docs):
    return math.log10((n_docs/doc_f))

# %% [markdown]
# Defining TF Weight function

# %%
# This is the Term Frequency (tf) Function

def tf_w(tf):
    if tf > 0:
        return (math.log10(1 + tf))
    else:
        return 0

# %% [markdown]
# Defining tf-idf weight function

# %%
# Returns the product of the term freq weight and the doc freq weight
def tf_idf(tf, doc_f, n_docs):
    return (tf_w(tf) * idf(doc_f, n_docs))

# %% [markdown]
# Function that computes tf-idf weight matrix

# %%
def comp_tf_idf(train, vocab):
    tf_idf_vs = []
    for doc, row in train.iterrows():
        doc_tf = row['Tf']   # getting term frequency for this doc
        tf_idf_v = {}
        for term in doc_tf.keys():
            if term in vocab.keys():
                tf_idf_v[term] = tf_idf(doc_tf[term], vocab[term], len(train))
        
        tf_idf_vs.append(tf_idf_v)
                
    return pd.DataFrame(tf_idf_vs).fillna(0)

# %% [markdown]
# Function that creates the models for each class

# %%
y_temp = []

def create_models(train, vocab):
    X = comp_tf_idf(train, vocab)
    n_samp, n_feat = X.shape
    models = []   # to store models for each class
    support = []
    
    for class_label in train['Label'].unique():
        # Create binary labels for the current class
        y = np.where(train['Label'] == class_label, 1.0, -1.0)
        
        # To accumulate results across batches
        all_support_v = []
        all_support_labels = []
        all_support_alphas = []
        
        batch_size = 2000
        
        # computing in batches as to not crash the kernel
        for i in range(0, n_samp, batch_size):
            # Select the current batch of data
            X_batch = X[i:i + batch_size]
            y_batch = y[i:i + batch_size]
            n_batch = len(y_batch)
        
            # Setup P matrix
            P = matrix(np.outer(y_batch, y_batch) * np.dot(X_batch, X_batch.T))
            #np.dot((y[:, np.newaxis] * X).T, (y[:, np.newaxis] * X))

            # Set up q vector -> a vector of -1s
            q = matrix(-np.ones((n_batch, 1)))
            
            #G and h for constraints
            G = matrix(np.vstack((-np.eye(n_batch), np.eye(n_batch))))  # -w <= 0 and w <= C
            h = matrix(np.hstack((np.zeros(n_batch), 100 * np.ones(n_batch))))
            
            # Set up A and b
            A = matrix(y_batch.reshape(1, -1))    # Shape: (1, n_samp)
            b = matrix(np.array([0.0]))
            
            # Solve the quadratic programming problem for the current class
            x = solvers.qp(P, q, G, h, A, b, solver='cvxopt')
            alphas = np.array(x['x']).flatten()  # Lagrange multipliers
            # Support vectors
            support_i = np.where(alphas > 1e-5)[0]
            support_v = X_batch.iloc[support_i]
            support_labels = y_batch[support_i]
            support_alphas = alphas[support_i]
            
             # Append the current batch's support vectors and their corresponding values
            all_support_v.append(support_v)
            all_support_labels.append(support_labels)
            all_support_alphas.append(support_alphas)
        
        # After looping through all batches for a given class, combine the results
        all_support_v = np.vstack(all_support_v)  # Combine all support vectors
        all_support_labels = np.hstack(all_support_labels)  # Combine all labels
        all_support_alphas = np.hstack(all_support_alphas)  # Combine all alphas
        
        # Average the alphas and support vectors (I found this to work better than just combining alphas)
        mean_alphas = np.mean(all_support_alphas)
        
        # Compute the weight vector for all batches combined
        w = np.dot(all_support_v.T, (mean_alphas * all_support_labels).T)
        
        # Store the coefficients for this class
        models.append(w)
        support.append((mean_alphas, all_support_labels, all_support_v))
    
    return models, support

# %%
def create_feat_v(tf, vocab):
    # Initializing the feature vector with zeros
    feat_v = np.zeros(len(vocab))
    # Creating an index mapping
    vocab_idx = {word: idx for idx, word in enumerate(vocab.keys())}
    
    for word, ct in tf.items():
        i = vocab_idx[word]
        feat_v[i] += ct
    
    return feat_v

# %% [markdown]
# Defining prediction function

# %%
def predict_svm(X, models):
    # Predicts the class with the highest score for each document
    scores = []
    
    for w in models:
        scores.append(np.dot(w.T, X))
    
    return np.argmax(scores)  # Return the class with the highest score

# %% [markdown]
# Testing model on train set first

# %% [markdown]
# Function that predicts the class of each doc based on the models passed in

# %%
def classify_docs_svm(data, vocab, models):
    for idx, row in data.iterrows():
        tf = row['Tf']
        x = create_feat_v(tf, vocab)
        data.at[idx, 'SVM Y-Hat'] = predict_svm(x, models)

# %% [markdown]
# Splitting data into train and test and then creating models with train

# %%
train, test = train_test_split(all_docs)

vocab = create_vocab(train)

models, support = create_models(train, vocab)
# Out:
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0001969510463746089, 'relative gap': 2.923690133501169e-07, 'primal objective': -673.6385778979821, 'dual objective': -673.6387748490287, 'primal infeasibility': 7.532263493638274e-14, 'dual infeasibility': 6.499791482764784e-15, 'primal slack': 5.58337169267361e-10, 'dual slack': 4.3318798524711964e-10, 'iterations': 18}
# [9.36677716e-09 2.70964861e-08 1.63191677e-08 1.34927562e-08
#  9.19152537e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0002888303364099561, 'relative gap': 6.176068364830969e-07, 'primal objective': -467.6605234078574, 'dual objective': -467.66081223819367, 'primal infeasibility': 1.0792626876774924e-13, 'dual infeasibility': 5.836147368978379e-15, 'primal slack': 6.994033475655135e-10, 'dual slack': 6.3869681079977e-10, 'iterations': 18}
# [3.55977817e-08 1.75749787e-01 1.56010230e-08 2.63516265e-08
#  3.37403446e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.5924243549364395e-05, 'relative gap': 9.88212873445988e-08, 'primal objective': -363.52737871237497, 'dual objective': -363.52741463661846, 'primal infeasibility': 2.7947899109947296e-14, 'dual infeasibility': 5.5678784924107545e-15, 'primal slack': 8.872098120955943e-11, 'dual slack': 7.13409200357946e-11, 'iterations': 17}
# [4.02759068e-09 1.54656251e-09 3.37388383e-10 1.57485553e-09
#  5.51433279e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.1597197662007378e-05, 'relative gap': 5.224114317173831e-08, 'primal objective': -413.41357311053525, 'dual objective': -413.41359470773284, 'primal infeasibility': 5.315192730392937e-14, 'dual infeasibility': 6.4718129839532786e-15, 'primal slack': 3.619727778232804e-11, 'dual slack': 3.5295302692940475e-11, 'iterations': 18}
# [5.67729031e-10 8.86053811e-10 4.75059584e-10 3.76387838e-10
#  1.80815313e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 7.426321294155682e-05, 'relative gap': 1.3908033343203986e-07, 'primal objective': -533.9591235438385, 'dual objective': -533.9591978070514, 'primal infeasibility': 1.0658141036401503e-14, 'dual infeasibility': 5.866035510717829e-15, 'primal slack': 1.8416792741570773e-10, 'dual slack': 1.385559349710707e-10, 'iterations': 17}
# [1.28755233e-09 3.51730854e-09 7.92775468e-09 1.23751602e-08
#  2.62318329e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 6.785533097184156e-05, 'relative gap': 7.626933902138896e-08, 'primal objective': -889.6803334405746, 'dual objective': -889.6804012959059, 'primal infeasibility': 3.5102573895168777e-13, 'dual infeasibility': 8.43882765847412e-14, 'primal slack': 1.5958347762907739e-10, 'dual slack': 1.2220580096774969e-10, 'iterations': 16}
# [3.00725281e-09 3.14923283e-08 7.19820615e-09 3.01295766e-09
#  3.77331940e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0002686192868392659, 'relative gap': 5.715165930750723e-07, 'primal objective': -470.0113524157662, 'dual objective': -470.011621035053, 'primal infeasibility': 6.039613253960852e-14, 'dual infeasibility': 7.283314111116626e-15, 'primal slack': 1.05457085514082e-09, 'dual slack': 5.097890008284971e-10, 'iterations': 16}
# [1.83844575e-08 1.15988522e+00 1.58177697e+00 1.24497223e-08
#  3.28630628e+00]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.388968424946475e-05, 'relative gap': 1.0674162038648798e-07, 'primal objective': -317.4926905433667, 'dual objective': -317.4927244330509, 'primal infeasibility': 1.8005991941622178e-14, 'dual infeasibility': 4.445503116967466e-15, 'primal slack': 1.0496038565263396e-10, 'dual slack': 5.1243871307556054e-11, 'iterations': 16}
# [8.69644613e-01 2.04658990e-09 9.60818063e-10 2.27640865e-09
#  2.47800777e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.9527428119144787e-05, 'relative gap': 7.218518459305654e-08, 'primal objective': -409.05108556008344, 'dual objective': -409.05111508751156, 'primal infeasibility': 1.5737296690432747e-14, 'dual infeasibility': 7.340671197649105e-15, 'primal slack': 6.817471528565123e-11, 'dual slack': 4.9370334093300014e-11, 'iterations': 16}
# [4.57464219e-01 4.11406713e-09 1.07270933e-09 1.45822305e-09
#  2.07921303e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0004016386968591338, 'relative gap': 5.606156308497724e-07, 'primal objective': -716.4243641411429, 'dual objective': -716.4247657798398, 'primal infeasibility': 7.490440386893711e-14, 'dual infeasibility': 7.357128547580826e-15, 'primal slack': 1.1991918222500046e-09, 'dual slack': 8.436127976294017e-10, 'iterations': 15}
# [7.00771576e-09 2.27752037e-08 3.90236660e-08 1.75645782e-08
#  2.06909168e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0003377561758464267, 'relative gap': 7.050198952624808e-07, 'primal objective': -479.0732546925916, 'dual objective': -479.0735924487675, 'primal infeasibility': 6.304117811322305e-14, 'dual infeasibility': 1.1435719462701284e-13, 'primal slack': 2.0245316949471982e-09, 'dual slack': 7.526744248582133e-10, 'iterations': 19}
# [3.37319565e-08 1.84619290e-06 3.14483421e+00 1.77356929e-08
#  7.76926110e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.4083969578349142e-05, 'relative gap': 5.600100819890726e-08, 'primal objective': -251.4949289542248, 'dual objective': -251.4949430381945, 'primal infeasibility': 6.905587213168474e-14, 'dual infeasibility': 4.078928044778582e-15, 'primal slack': 1.2268065560322273e-10, 'dual slack': 2.476471083999822e-11, 'iterations': 16}
# [1.46014046e-09 1.52314049e-09 1.93015864e-09 9.38294050e-10
#  5.25160513e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 6.534813617162531e-05, 'relative gap': 1.327037921047765e-07, 'primal objective': -492.43608743320294, 'dual objective': -492.4361527813392, 'primal infeasibility': 7.714600514507153e-14, 'dual infeasibility': 6.436270277937576e-15, 'primal slack': 2.75369644384339e-10, 'dual slack': 1.19580592256158e-10, 'iterations': 16}
# [1.96733888e-09 7.15190068e-09 8.48994213e-02 1.94719476e-09
#  4.72757413e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 6.613976331444293e-05, 'relative gap': 1.5114366338947455e-07, 'primal objective': -437.59534360372544, 'dual objective': -437.5954097434889, 'primal infeasibility': 1.2256862191861728e-13, 'dual infeasibility': 6.384871966134182e-15, 'primal slack': 2.809619935636904e-10, 'dual slack': 1.5640831336701092e-10, 'iterations': 17}
# [3.86455895e-09 6.15425647e-09 9.50613601e-01 2.08263122e-09
#  6.37574060e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 5.009377734903791e-06, 'relative gap': 2.0763408999639627e-08, 'primal objective': -241.25988824815494, 'dual objective': -241.2598932575327, 'primal infeasibility': 1.2502491514589452e-14, 'dual infeasibility': 3.576402817442903e-15, 'primal slack': 2.6509473397622965e-11, 'dual slack': 7.828223673180025e-12, 'iterations': 17}
# [1.40472147e-10 2.62628109e+00 4.86260082e-10 5.11498560e-10
#  1.45942850e+00]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00022682102030400337, 'relative gap': 2.3211846088732828e-07, 'primal objective': -977.177857534148, 'dual objective': -977.1780843551683, 'primal infeasibility': 3.907985046680551e-14, 'dual infeasibility': 9.465710023542699e-15, 'primal slack': 6.199406481202496e-10, 'dual slack': 4.50158050741128e-10, 'iterations': 16}
# [9.81914515e-09 2.48950787e-08 7.98920572e-09 3.91955969e-08
#  4.61022910e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0002425614381304246, 'relative gap': 2.617314672664808e-07, 'primal objective': -926.756880491797, 'dual objective': -926.7571230532352, 'primal infeasibility': 1.1920203162005175e-13, 'dual infeasibility': 8.501728579332623e-15, 'primal slack': 1.2991162741300699e-09, 'dual slack': 5.290726267150669e-10, 'iterations': 16}
# [2.06004365e-08 3.88309318e-08 5.85252892e-08 1.13002738e-08
#  3.80385753e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 6.066812295350297e-05, 'relative gap': 9.312828812655238e-08, 'primal objective': -651.4467749161332, 'dual objective': -651.4468355842562, 'primal infeasibility': 4.4853010194856324e-14, 'dual infeasibility': 6.974725925560895e-15, 'primal slack': 1.9532739112454043e-10, 'dual slack': 1.0840430331743763e-10, 'iterations': 16}
# [3.62025869e-09 1.91736033e-09 5.75539866e-10 3.53754942e-09
#  1.69212357e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00016771635799760058, 'relative gap': 2.5300972969450496e-07, 'primal objective': -662.8850131578287, 'dual objective': -662.8851808741867, 'primal infeasibility': 1.4299672557172016e-13, 'dual infeasibility': 9.159696948342854e-15, 'primal slack': 4.808721852325353e-10, 'dual slack': 3.4478881576890476e-10, 'iterations': 16}
# [1.54102826e-08 2.33389191e-08 6.04431371e-09 8.60006903e-01
#  1.28507334e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.00786062790132e-05, 'relative gap': 1.9531505424667552e-08, 'primal objective': -1028.0111974192569, 'dual objective': -1028.0112174978633, 'primal infeasibility': 2.2316490804539293e-13, 'dual infeasibility': 6.973461203231239e-15, 'primal slack': 4.979266491884643e-11, 'dual slack': 3.603117804531591e-11, 'iterations': 20}
# [3.38239979e-10 1.01627043e-09 3.23149779e+00 2.03146557e+00
#  1.09524317e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0007559603182707771, 'relative gap': 4.63201159592063e-07, 'primal objective': -1632.0345979628903, 'dual objective': -1632.0353539232085, 'primal infeasibility': 2.842170943040401e-14, 'dual infeasibility': 1.4155447378335507e-14, 'primal slack': 1.3165371307060877e-09, 'dual slack': 1.378284058133948e-09, 'iterations': 15}
# [2.43439769e-07 9.97789762e-08 8.26614828e-08 4.63443847e-07
#  3.01223633e-07]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0005326618934829292, 'relative gap': 5.448343204883861e-07, 'primal objective': -977.6584797474843, 'dual objective': -977.659012409378, 'primal infeasibility': 1.6983509044868401e-13, 'dual infeasibility': 1.3199538476555598e-14, 'primal slack': 1.1679849439844205e-09, 'dual slack': 9.610277530918517e-10, 'iterations': 16}
# [2.03161680e-08 2.03662891e-08 3.31145645e-08 6.96611241e-08
#  2.91153734e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 9.65522851200479e-05, 'relative gap': 7.690920286171528e-08, 'primal objective': -1255.406135123405, 'dual objective': -1255.40623167569, 'primal infeasibility': 1.2355751955369393e-13, 'dual infeasibility': 1.2113011935108812e-14, 'primal slack': 2.708379363979656e-10, 'dual slack': 2.09916231814351e-10, 'iterations': 16}
# [4.12094536e-09 3.24739345e-09 9.56034250e-10 2.49514690e-09
#  7.72729043e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 4.432510598468905e-05, 'relative gap': 5.3076871975442574e-08, 'primal objective': -835.1114964950692, 'dual objective': -835.1115408201755, 'primal infeasibility': 2.0189405702808472e-13, 'dual infeasibility': 1.2759591203757046e-14, 'primal slack': 1.4375889814961841e-10, 'dual slack': 9.337881173419151e-11, 'iterations': 16}
# [1.17206298e-08 4.08940254e-09 3.02203038e-09 1.83526386e+00
#  2.02806846e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.9839021145906672e-05, 'relative gap': 2.800944579644845e-08, 'primal objective': -708.2975254163089, 'dual objective': -708.29754525533, 'primal infeasibility': 1.7909161351936108e-14, 'dual infeasibility': 7.727183933849751e-15, 'primal slack': 4.198195531749241e-11, 'dual slack': 3.0845215190122274e-11, 'iterations': 17}
# [1.13832306e-09 5.68331134e-10 1.83270224e-09 1.47581548e-09
#  2.24684210e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.6894604823094932e-05, 'relative gap': 2.9718314718132012e-08, 'primal objective': -568.4913489655939, 'dual objective': -568.4913658601989, 'primal infeasibility': 4.227212987500792e-14, 'dual infeasibility': 7.913518277729047e-15, 'primal slack': 6.23773629353165e-11, 'dual slack': 3.33429093058079e-11, 'iterations': 17}
# [7.68557569e-10 1.40703188e-09 3.03914808e-09 6.35443958e-09
#  6.22016262e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.3434805812472071e-05, 'relative gap': 1.9450671557548685e-08, 'primal objective': -690.7116688862142, 'dual objective': -690.7116823210198, 'primal infeasibility': 1.1501910535116622e-13, 'dual infeasibility': 1.087356898901466e-14, 'primal slack': 5.732182093113437e-11, 'dual slack': 2.7354816810154362e-11, 'iterations': 17}
# [5.16853399e-09 8.66180293e-09 5.62292534e-10 2.03216150e+00
#  6.97290307e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.3748562827301505e-05, 'relative gap': 2.74922615379084e-08, 'primal objective': -863.8271825893696, 'dual objective': -863.8272063379326, 'primal infeasibility': 1.211302257171826e-13, 'dual infeasibility': 8.84426674757922e-15, 'primal slack': 3.841320301223878e-11, 'dual slack': 2.595082407005529e-11, 'iterations': 17}
# [1.79726358e-09 3.71772882e-10 1.13379918e-10 3.30238762e-10
#  1.26412048e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0008003196690115623, 'relative gap': 9.605112775850845e-07, 'primal objective': -833.2225635327515, 'dual objective': -833.2233638524204, 'primal infeasibility': 2.842170943040401e-14, 'dual infeasibility': 9.095006064592898e-15, 'primal slack': 1.3908456582371602e-09, 'dual slack': 1.7293042906063088e-09, 'iterations': 16}
# [2.66082346e-08 5.42336208e-01 3.72354863e-08 4.49393092e-08
#  4.96582604e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 5.2837090533731346e-05, 'relative gap': 6.597657645129477e-08, 'primal objective': -800.8461999045487, 'dual objective': -800.8462527416392, 'primal infeasibility': 7.105427357601002e-15, 'dual infeasibility': 1.0143039724293152e-14, 'primal slack': 1.5374369077470032e-10, 'dual slack': 9.257006234162751e-11, 'iterations': 16}
# [1.45969605e-09 1.80914493e-09 3.34553952e-09 2.59024323e-09
#  7.37435350e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 4.404762048338899e-05, 'relative gap': 5.1201305173929015e-08, 'primal objective': -860.2831575046922, 'dual objective': -860.2832015523127, 'primal infeasibility': 2.856048730848215e-14, 'dual infeasibility': 9.505530951503866e-15, 'primal slack': 5.3136915482183993e-11, 'dual slack': 5.4169928305640887e-11, 'iterations': 17}
# [2.22906329e+00 3.91539474e-09 2.49710739e-09 4.41440386e-09
#  1.41888556e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00027523216987210893, 'relative gap': 4.539698516947514e-07, 'primal objective': -606.2785201365632, 'dual objective': -606.2787953687331, 'primal infeasibility': 1.7763568394002505e-14, 'dual infeasibility': 8.466059686601854e-15, 'primal slack': 7.779210710258623e-10, 'dual slack': 6.298691306109954e-10, 'iterations': 17}
# [4.93151623e+00 6.44043965e-08 1.05663214e+00 1.58442400e-08
#  4.97055544e-04]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.3045682178562595e-05, 'relative gap': 6.457029056940111e-08, 'primal objective': -356.90844776039455, 'dual objective': -356.90847080607676, 'primal infeasibility': 2.759130906198437e-14, 'dual infeasibility': 5.8895929028809656e-15, 'primal slack': 6.443012783792277e-11, 'dual slack': 3.69178145532706e-11, 'iterations': 17}
# [7.60627743e-01 2.52250456e-09 2.10820726e-10 7.85330959e-09
#  1.09579035e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 4.966760854301627e-05, 'relative gap': 8.563757783243669e-08, 'primal objective': -579.9744668187452, 'dual objective': -579.9745164863538, 'primal infeasibility': 1.9505958709292045e-15, 'dual infeasibility': 9.03104216865924e-15, 'primal slack': 1.347096091630995e-10, 'dual slack': 1.0209552402791953e-10, 'iterations': 17}
# [1.79371885e-09 3.30727577e-09 3.51121221e-09 1.13954898e-09
#  4.51187984e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.3053414437731736e-05, 'relative gap': 1.0160758940108736e-07, 'primal objective': -325.3045823895711, 'dual objective': -325.30461544298544, 'primal infeasibility': 7.172040739078511e-14, 'dual infeasibility': 4.862667940549062e-15, 'primal slack': 1.2880954836635438e-10, 'dual slack': 6.12425050677562e-11, 'iterations': 18}
# [9.94022920e-10 1.78260916e-09 4.14799982e-09 7.04343936e-01
#  3.66815071e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.5473671403625067e-06, 'relative gap': 8.640769418227059e-07, 'primal objective': -4.105383408194646, 'dual objective': -4.105386955561786, 'primal infeasibility': 2.1654763818735082e-16, 'dual infeasibility': 2.1178702417964804e-16, 'primal slack': 6.733817933671896e-10, 'dual slack': 8.826130565704059e-12, 'iterations': 17}
# [6.55670614e-09 2.70662449e-08 1.17541808e-08 3.18276018e-09
#  5.43556758e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.3358713357600608e-06, 'relative gap': 3.745551514619181e-07, 'primal objective': -3.5665544327612375, 'dual objective': -3.5665557686325724, 'primal infeasibility': 1.0468172880974722e-15, 'dual infeasibility': 1.7686453464445378e-16, 'primal slack': 1.2127288391386265e-10, 'dual slack': 3.1675702851069016e-12, 'iterations': 19}
# [2.89795285e-08 2.09630535e-02 6.83587774e-09 3.25625257e-09
#  3.90461390e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.1117361237258263e-07, 'relative gap': 2.888394938093226e-08, 'primal objective': -3.848975460605602, 'dual objective': -3.848975571779216, 'primal infeasibility': 1.412064909445121e-15, 'dual infeasibility': 2.282958347620956e-16, 'primal slack': 1.2335959467607405e-11, 'dual slack': 2.381393058009354e-13, 'iterations': 18}
# [4.58118639e-10 8.40906008e-09 3.96661259e-11 1.40770644e-10
#  2.68008239e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.3867418284141245e-07, 'relative gap': 3.8372296897041325e-08, 'primal objective': -3.6139140488122523, 'dual objective': -3.613914187486436, 'primal infeasibility': 7.494005416219807e-16, 'dual infeasibility': 2.4544362763085096e-16, 'primal slack': 1.6191627226666332e-11, 'dual slack': 3.0899586006421425e-13, 'iterations': 18}
# [5.27378884e-10 1.20940108e-09 3.76235368e-10 1.21842490e-10
#  9.99691949e-02]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.26124230207392e-06, 'relative gap': 8.981709248433566e-07, 'primal objective': -3.6309818230229274, 'dual objective': -3.63098508426523, 'primal infeasibility': 2.3765711620882257e-16, 'dual infeasibility': 1.766862068166644e-16, 'primal slack': 3.5008034382627195e-10, 'dual slack': 8.080815195886499e-12, 'iterations': 18}
# [3.89980113e-09 7.04953604e-02 1.39441567e-07 1.33339312e-08
#  7.70150591e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00017198154905297643, 'relative gap': 5.219958554630673e-07, 'primal objective': -329.46918496203386, 'dual objective': -329.46935694358297, 'primal infeasibility': 5.115321086922683e-14, 'dual infeasibility': 3.2164612457430236e-14, 'primal slack': 1.0330173532616888e-09, 'dual slack': 3.6920024939176805e-10, 'iterations': 18}
# [2.08401010e-07 2.58419442e-08 8.73263850e-06 3.60717958e-08
#  1.93352136e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.1685471557866335e-05, 'relative gap': 6.784928095945563e-08, 'primal objective': -466.99789754294477, 'dual objective': -466.99792922841647, 'primal infeasibility': 8.065167798887843e-14, 'dual infeasibility': 1.3264866687260185e-14, 'primal slack': 2.702601081095858e-10, 'dual slack': 6.355150505512025e-11, 'iterations': 17}
# [2.81536225e-01 1.03365101e-08 3.18722848e-09 3.68372943e-09
#  2.98999858e-07]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0001027774593903481, 'relative gap': 2.497843714665672e-07, 'primal objective': -411.46473170802244, 'dual objective': -411.4648344854818, 'primal infeasibility': 3.4420737101358914e-14, 'dual infeasibility': 1.3696433236467368e-14, 'primal slack': 2.796685711719361e-10, 'dual slack': 1.8364146667812293e-10, 'iterations': 18}
# [4.39918095e-09 3.35339163e-09 1.61061973e-09 1.50514540e-01
#  1.04903786e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 9.161214639812781e-05, 'relative gap': 1.8794047830344613e-07, 'primal objective': -487.4529809922698, 'dual objective': -487.4530726044161, 'primal infeasibility': 7.118622527512324e-14, 'dual infeasibility': 6.465227914957069e-15, 'primal slack': 2.82804034842501e-10, 'dual slack': 1.6527553950910293e-10, 'iterations': 17}
# [7.71215929e-09 1.19006272e-08 8.27447162e-09 3.86382289e-09
#  1.10905167e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 4.55737683355357e-05, 'relative gap': 2.414338281994711e-07, 'primal objective': -188.76297772937994, 'dual objective': -188.76302330314834, 'primal infeasibility': 3.30050102600333e-14, 'dual infeasibility': 3.8669224847081945e-15, 'primal slack': 2.7113789083046474e-10, 'dual slack': 9.977925977406379e-11, 'iterations': 21}
# [3.23704208e-09 2.43221700e-01 4.63824586e-09 4.37377362e-09
#  2.46027587e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 7.888319134184482e-05, 'relative gap': 1.083009140889879e-07, 'primal objective': -728.3705036600952, 'dual objective': -728.3705825432867, 'primal infeasibility': 7.068507404634634e-14, 'dual infeasibility': 8.366385734486628e-15, 'primal slack': 2.797324331571504e-10, 'dual slack': 1.463469949386316e-10, 'iterations': 17}
# [4.69738557e-09 1.41940108e-08 4.15157340e-09 2.27013933e-09
#  1.47090529e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0002328207506298352, 'relative gap': 3.1484482214304724e-07, 'primal objective': -739.4777816103165, 'dual objective': -739.4780144310671, 'primal infeasibility': 1.7763568394002505e-15, 'dual infeasibility': 9.63087881636618e-15, 'primal slack': 4.4046209187602754e-10, 'dual slack': 4.0785164187426446e-10, 'iterations': 16}
# [1.61338242e-08 5.02905853e-08 6.89681199e-09 6.28268167e-09
#  7.02992956e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 4.1687423297084216e-05, 'relative gap': 3.806813441878473e-08, 'primal objective': -1095.073975479963, 'dual objective': -1095.0740171673865, 'primal infeasibility': 1.7505743557596011e-16, 'dual infeasibility': 1.4481538378955317e-14, 'primal slack': 9.594563430859654e-11, 'dual slack': 7.029843939802864e-11, 'iterations': 16}
# [1.42671968e-09 1.08992854e-09 1.81628128e-10 2.30592883e+00
#  2.47657094e+00]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0004846727821931784, 'relative gap': 6.107606919769738e-07, 'primal objective': -793.5559517170941, 'dual objective': -793.5564363898765, 'primal infeasibility': 8.04708718348088e-14, 'dual infeasibility': 1.0873963686646754e-14, 'primal slack': 9.408565045323407e-10, 'dual slack': 9.874675087121689e-10, 'iterations': 15}
# [2.01330702e-08 3.44410482e-08 1.06033680e-08 1.23301093e-08
#  3.10448064e-04]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00016959112204747935, 'relative gap': 2.4695012676606e-07, 'primal objective': -686.7423972134093, 'dual objective': -686.7425668045313, 'primal infeasibility': 3.019806626980426e-14, 'dual infeasibility': 9.418824021913492e-15, 'primal slack': 3.6724319838525266e-10, 'dual slack': 2.3917422487560384e-10, 'iterations': 16}
# [1.53234832e-09 5.72492101e-09 8.13155807e-09 2.44364457e-08
#  6.06967672e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 9.958670868662425e-05, 'relative gap': 2.975908497910173e-07, 'primal objective': -334.6430468428679, 'dual objective': -334.6431464295766, 'primal infeasibility': 1.2014728318591231e-15, 'dual infeasibility': 3.934485827164132e-14, 'primal slack': 6.899474263989458e-10, 'dual slack': 2.2364926093974801e-10, 'iterations': 16}
# [1.20439275e-08 1.71986081e+00 2.85898431e-01 1.56266910e-08
#  1.85221862e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 5.824294325240665e-06, 'relative gap': 1.731092293962497e-08, 'primal objective': -336.45198153524007, 'dual objective': -336.4519873595344, 'primal infeasibility': 3.4969052092026666e-14, 'dual infeasibility': 4.392721138996983e-15, 'primal slack': 1.3187129509939736e-11, 'dual slack': 8.152417538902673e-12, 'iterations': 19}
# [1.14513893e-09 1.40027106e-09 4.12726193e-06 2.20355974e-10
#  3.01936398e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00010821030843532518, 'relative gap': 4.898982629672976e-07, 'primal objective': -220.88322538622393, 'dual objective': -220.88333359653237, 'primal infeasibility': 6.106226635438361e-15, 'dual infeasibility': 4.5823347737602195e-15, 'primal slack': 4.497130690369081e-10, 'dual slack': 2.2479777402696762e-10, 'iterations': 17}
# [1.44657122e-08 8.66372911e-09 5.34739067e-09 1.35914080e-08
#  4.13385143e-01]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.181505427504299e-05, 'relative gap': 5.8799034208668784e-08, 'primal objective': -541.081238887976, 'dual objective': -541.0812707030304, 'primal infeasibility': 1.1609461260140798e-13, 'dual infeasibility': 4.050175313177304e-14, 'primal slack': 1.0556680014127886e-10, 'dual slack': 6.95468450224045e-11, 'iterations': 18}
# [1.19779948e-01 4.22704156e-09 9.70522430e-01 1.35781416e-09
#  5.29122359e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.1457409555803326e-05, 'relative gap': 2.7160519264061638e-08, 'primal objective': -421.8405931201612, 'dual objective': -421.8406045775708, 'primal infeasibility': 1.8637492794373724e-14, 'dual infeasibility': 4.680449203356449e-14, 'primal slack': 5.564335761179363e-11, 'dual slack': 2.459498172848956e-11, 'iterations': 17}
# [1.08578962e-09 5.79583883e-10 1.90986932e-09 1.06775016e-09
#  1.03123153e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 4.583576672236329e-05, 'relative gap': 1.2846121701522806e-07, 'primal objective': -356.8062625230292, 'dual objective': -356.80630835879595, 'primal infeasibility': 1.737601502025675e-15, 'dual infeasibility': 1.2303963209589092e-14, 'primal slack': 3.1134671261816435e-10, 'dual slack': 9.068600950538423e-11, 'iterations': 18}
# [8.03086824e-09 5.07912864e-09 6.39908131e-01 3.59267331e-09
#  6.03420389e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00048210076935177956, 'relative gap': 5.962389199789989e-07, 'primal objective': -808.5697749632989, 'dual objective': -808.5702570640682, 'primal infeasibility': 1.0456338824849955e-14, 'dual infeasibility': 2.4660505611107575e-14, 'primal slack': 2.3869271329026934e-09, 'dual slack': 1.0370512223356325e-09, 'iterations': 15}
# [6.78870793e-08 6.53398707e-01 4.99751003e-08 1.61415735e-07
#  1.75305872e-07]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0003149517714966105, 'relative gap': 4.803700709302924e-07, 'primal objective': -655.6440347889907, 'dual objective': -655.6443497407622, 'primal infeasibility': 2.609024107869118e-14, 'dual infeasibility': 1.3285987211570098e-14, 'primal slack': 1.6241031188760802e-09, 'dual slack': 6.387425375332607e-10, 'iterations': 16}
# [6.15581306e-08 6.22030383e-02 7.52251946e-09 1.18768282e-07
#  5.62523197e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.2181100064908846e-05, 'relative gap': 5.3623291560897965e-08, 'primal objective': -227.16061827490068, 'dual objective': -227.16063045600075, 'primal infeasibility': 8.262796648006278e-15, 'dual infeasibility': 5.126656682982835e-15, 'primal slack': 3.06664565314569e-11, 'dual slack': 1.3857885808109287e-11, 'iterations': 17}
# [1.62591214e+00 1.95929783e+00 3.59154947e-10 4.43678804e-10
#  6.32718740e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 7.531426991864727e-05, 'relative gap': 1.6506680250101793e-07, 'primal objective': -456.2653954491111, 'dual objective': -456.2654707633811, 'primal infeasibility': 2.4453355450232347e-14, 'dual infeasibility': 1.899362352158954e-14, 'primal slack': 2.8460630346515887e-10, 'dual slack': 1.531025024779301e-10, 'iterations': 17}
# [1.41363266e-09 3.73849851e-09 3.41679832e-08 2.64483298e-07
#  3.72505493e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 5.5646732854783656e-05, 'relative gap': 2.413734713159442e-07, 'primal objective': -230.54204155661017, 'dual objective': -230.54209720334293, 'primal infeasibility': 5.350451470762621e-14, 'dual infeasibility': 4.459154132986152e-15, 'primal slack': 2.458670447843592e-10, 'dual slack': 9.750619544522544e-11, 'iterations': 19}
# [3.85446185e-09 1.88060992e-08 2.11182215e-09 7.48816125e-09
#  6.17406719e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 5.3060314905454394e-06, 'relative gap': 2.871387529770091e-08, 'primal objective': -184.789807559354, 'dual objective': -184.78981286538544, 'primal infeasibility': 1.2878587085651816e-14, 'dual infeasibility': 3.424768938733843e-15, 'primal slack': 2.9511762858850075e-11, 'dual slack': 5.758665202038342e-12, 'iterations': 18}
# [1.11746569e-09 8.56563852e-10 3.26165617e+00 2.22483790e-10
#  3.03971940e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.9780333859350956e-05, 'relative gap': 2.1656524921868166e-07, 'primal objective': -91.33660146636599, 'dual objective': -91.33662124669986, 'primal infeasibility': 1.2426445040927978e-14, 'dual infeasibility': 1.9499343116598108e-15, 'primal slack': 4.3200274225941635e-10, 'dual slack': 4.417856121493959e-11, 'iterations': 18}
# [1.45072476e-09 1.77511579e-09 1.11190578e-08 2.40051528e-09
#  4.48580236e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 6.579652749484796e-05, 'relative gap': 3.9488297792540155e-07, 'primal objective': -166.62285075067928, 'dual objective': -166.6229165472068, 'primal infeasibility': 2.0095036745715333e-14, 'dual infeasibility': 3.1063185293041243e-15, 'primal slack': 3.451976101015718e-10, 'dual slack': 1.3819700494451735e-10, 'iterations': 17}
# [1.97136963e-08 1.17731275e-08 1.01315269e-08 7.90788731e-09
#  5.06791956e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.418360005697043e-05, 'relative gap': 2.122303456426694e-07, 'primal objective': -113.94977463631977, 'dual objective': -113.94979881991983, 'primal infeasibility': 1.4254305500310344e-15, 'dual infeasibility': 2.3439258964980514e-15, 'primal slack': 1.7482113471878642e-10, 'dual slack': 4.522475218571847e-11, 'iterations': 18}
# [1.65869128e-09 3.40471339e-01 4.53234314e-09 3.26093802e-09
#  2.48843199e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00040647681607293407, 'relative gap': 8.205540565078786e-07, 'primal objective': -495.3687241555075, 'dual objective': -495.3691306323236, 'primal infeasibility': 2.898858617741439e-14, 'dual infeasibility': 6.09422744806826e-15, 'primal slack': 1.0389089026265211e-09, 'dual slack': 9.026570501154603e-10, 'iterations': 16}
# [1.17165049e-07 8.84559901e-08 4.92380743e-01 2.45882542e-08
#  5.71398980e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.6132704768209435e-05, 'relative gap': 1.1596723522904602e-07, 'primal objective': -311.5768406209219, 'dual objective': -311.5768767536267, 'primal infeasibility': 2.1316282072803006e-14, 'dual infeasibility': 5.507168211325359e-15, 'primal slack': 7.892662760196901e-11, 'dual slack': 5.94650470832644e-11, 'iterations': 18}
# [4.04904774e-09 5.71492564e-09 8.73045969e-09 1.50285056e-09
#  3.11490649e+00]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0004501436073494105, 'relative gap': 8.752084038385663e-07, 'primal objective': -514.327336637915, 'dual objective': -514.3277867815224, 'primal infeasibility': 2.7353940279430388e-14, 'dual infeasibility': 5.856617153733674e-15, 'primal slack': 2.1217038818408062e-09, 'dual slack': 9.987634400988977e-10, 'iterations': 16}
# [4.68130180e-08 8.65238513e-08 5.54360897e-09 3.95162765e-08
#  1.88775175e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.837773578538455e-05, 'relative gap': 4.316028570480425e-08, 'primal objective': -425.8019956373665, 'dual objective': -425.8020140151025, 'primal infeasibility': 1.606410896095398e-13, 'dual infeasibility': 6.949294331074536e-15, 'primal slack': 3.940910709312018e-11, 'dual slack': 2.6586408583846113e-11, 'iterations': 17}
# [5.38829237e-09 4.40333059e-08 2.56912087e-09 7.85278116e-10
#  6.92458094e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0003078342530618201, 'relative gap': 5.862888416367082e-07, 'primal objective': -525.0556230994559, 'dual objective': -525.055930933709, 'primal infeasibility': 4.722814801837912e-14, 'dual infeasibility': 7.013006521621386e-15, 'primal slack': 7.671214402016651e-10, 'dual slack': 6.090472656948874e-10, 'iterations': 17}
# [8.24839334e-09 4.14445653e-08 1.41572854e-07 2.53293911e-08
#  1.42510394e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00013787888069677058, 'relative gap': 1.7322223667260247e-07, 'primal objective': -795.9652487190062, 'dual objective': -795.9653865978867, 'primal infeasibility': 1.2736276974966247e-13, 'dual infeasibility': 6.88302814772016e-14, 'primal slack': 9.34551059487539e-10, 'dual slack': 2.9991900305322464e-10, 'iterations': 16}
# [2.51673871e-08 1.04322431e-01 6.92178187e-08 1.22385107e-08
#  5.57973832e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 4.342093394683857e-05, 'relative gap': 4.961865191771949e-08, 'primal objective': -875.092979527974, 'dual objective': -875.0930229489084, 'primal infeasibility': 3.0152003942822317e-13, 'dual infeasibility': 2.895022658720531e-14, 'primal slack': 1.6660068255371898e-10, 'dual slack': 6.80373731586768e-11, 'iterations': 17}
# [6.27618740e+00 4.88289731e-09 9.34160425e-09 1.47405355e-08
#  7.08768960e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 8.851151994900808e-05, 'relative gap': 8.13438202413572e-08, 'primal objective': -1088.1160939624353, 'dual objective': -1088.116182473956, 'primal infeasibility': 2.929878561985788e-13, 'dual infeasibility': 6.534372206870455e-14, 'primal slack': 5.168402119263193e-10, 'dual slack': 1.8435707440933286e-10, 'iterations': 16}
# [3.12408891e-09 4.75524499e-09 8.61338001e-03 1.97058949e-07
#  2.85535988e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 1.2440741776501428e-05, 'relative gap': 4.0633707503337736e-08, 'primal objective': -306.1680201217061, 'dual objective': -306.16803256244793, 'primal infeasibility': 2.1649043540440645e-14, 'dual infeasibility': 8.093450969258724e-15, 'primal slack': 5.6567628286334804e-11, 'dual slack': 2.6992540060566805e-11, 'iterations': 17}
# [2.92221547e-09 2.74196447e-09 3.20485407e+00 3.89220371e-10
#  5.61950340e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00010091588280467572, 'relative gap': 1.5126227223896862e-07, 'primal objective': -667.1583158902031, 'dual objective': -667.1584168060859, 'primal infeasibility': 4.055089597443384e-14, 'dual infeasibility': 4.893441294946345e-14, 'primal slack': 3.710850241631631e-10, 'dual slack': 2.171402259885594e-10, 'iterations': 19}
# [3.58786604e-09 7.63565596e-09 8.94202720e-09 1.26627522e-08
#  8.93594093e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 7.660403142076e-05, 'relative gap': 7.132352273310047e-08, 'primal objective': -1074.036005027678, 'dual objective': -1074.0360816317093, 'primal infeasibility': 3.696926554703487e-14, 'dual infeasibility': 7.670907416698626e-14, 'primal slack': 4.1160207029633345e-10, 'dual slack': 1.477679512585895e-10, 'iterations': 17}
# [5.96552813e-09 5.39997048e-09 8.72907869e-09 1.09361963e-08
#  1.40761614e-01]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0004925052420715676, 'relative gap': 3.963617457405225e-07, 'primal objective': -1242.5650239061802, 'dual objective': -1242.565516411422, 'primal infeasibility': 1.1210176887379306e-13, 'dual infeasibility': 3.488831768231358e-14, 'primal slack': 2.438435268693235e-09, 'dual slack': 1.0842080169580511e-09, 'iterations': 15}
# [1.79426951e+00 8.56083004e+00 4.54876091e-08 3.05586302e-08
#  4.45391719e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00012829585491097958, 'relative gap': 8.996155140376842e-08, 'primal objective': -1426.1187463870856, 'dual objective': -1426.1188746829403, 'primal infeasibility': 1.8918200339612667e-13, 'dual infeasibility': 6.649593633700269e-14, 'primal slack': 5.612798374901025e-10, 'dual slack': 2.388273514786236e-10, 'iterations': 16}
# [6.38012425e-09 4.29850356e-08 6.18584255e-09 4.29913081e-09
#  6.53790709e-07]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 6.701890847471606e-05, 'relative gap': 1.3248522181528633e-07, 'primal objective': -505.85950309352404, 'dual objective': -505.8595701124325, 'primal infeasibility': 4.5056708952881444e-15, 'dual infeasibility': 4.5144752236663895e-14, 'primal slack': 2.2726785784620507e-10, 'dual slack': 1.2192245570320067e-10, 'iterations': 17}
# [3.43038020e-09 5.98172986e-01 2.39118091e-06 1.60106826e-09
#  2.05837127e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0004374377593503873, 'relative gap': 4.147571191666083e-07, 'primal objective': -1054.6841491939965, 'dual objective': -1054.6845866317556, 'primal infeasibility': 1.734656255442113e-13, 'dual infeasibility': 6.720625427893396e-14, 'primal slack': 2.3730249743424097e-09, 'dual slack': 1.0381943942936903e-09, 'iterations': 15}
# [1.20951400e-08 2.72929368e-08 1.31550293e-07 5.82236009e-08
#  2.96275846e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00025486922221775994, 'relative gap': 4.2549541846526196e-07, 'primal objective': -598.9940458984468, 'dual objective': -598.9943007676688, 'primal infeasibility': 1.1442109490232788e-13, 'dual infeasibility': 7.555104576801782e-15, 'primal slack': 5.268909902185405e-10, 'dual slack': 4.5104972533140854e-10, 'iterations': 17}
# [1.39148390e+00 1.81421098e-08 8.71464736e-09 1.79105339e-08
#  1.14104061e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 5.0887242698864514e-05, 'relative gap': 5.71140439516919e-08, 'primal objective': -890.9760048142602, 'dual objective': -890.9760557015026, 'primal infeasibility': 2.9198865547641617e-13, 'dual infeasibility': 1.0294435801858541e-14, 'primal slack': 1.9511315575934382e-10, 'dual slack': 9.522775653296937e-11, 'iterations': 18}
# [2.52970989e-09 7.86498478e-09 6.04868855e-04 1.91205803e-09
#  1.92877612e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00020920462170475915, 'relative gap': 3.499639068398996e-07, 'primal objective': -597.789136582206, 'dual objective': -597.7893457868277, 'primal infeasibility': 3.7165062741667914e-14, 'dual infeasibility': 8.058551169720543e-15, 'primal slack': 5.711945532855134e-10, 'dual slack': 4.525694405613745e-10, 'iterations': 17}
# [1.09453122e-08 2.06934684e-08 1.96331067e-09 1.63670280e-08
#  1.18670300e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0007417206683372191, 'relative gap': 9.273088761412413e-07, 'primal objective': -799.8636564589999, 'dual objective': -799.8643981796682, 'primal infeasibility': 3.6415315207705135e-14, 'dual infeasibility': 9.518298510511209e-15, 'primal slack': 1.7499574144896837e-09, 'dual slack': 1.5533451130752436e-09, 'iterations': 16}
# [3.20897740e-08 8.82877066e-08 4.28901344e+00 2.67019530e-08
#  1.20781376e-07]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00020292592493808593, 'relative gap': 4.910023579056149e-07, 'primal objective': -413.28910476860534, 'dual objective': -413.28930769453024, 'primal infeasibility': 7.105427357601002e-14, 'dual infeasibility': 6.2738120520994315e-15, 'primal slack': 4.0385930356069146e-10, 'dual slack': 3.4819800755617633e-10, 'iterations': 17}
# [4.71365135e-09 3.50958291e-07 4.53812208e-08 3.05597173e-08
#  1.02843715e-07]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 5.729517614313032e-06, 'relative gap': 2.506664128753694e-08, 'primal objective': -228.5714128426823, 'dual objective': -228.57141857219997, 'primal infeasibility': 4.829470157119431e-14, 'dual infeasibility': 4.452532220477813e-15, 'primal slack': 1.610922473013741e-11, 'dual slack': 7.91808869828677e-12, 'iterations': 19}
# [1.47027986e-01 5.80156997e-10 9.82168992e-07 3.38614905e-10
#  1.59120111e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.616250663930917e-05, 'relative gap': 7.26462479743812e-08, 'primal objective': -360.135689988221, 'dual objective': -360.1357161507276, 'primal infeasibility': 2.6867397195928788e-14, 'dual infeasibility': 5.3853099038009046e-15, 'primal slack': 7.07104443886878e-11, 'dual slack': 5.112305506260527e-11, 'iterations': 17}
# [1.99711517e-09 1.20645234e+00 2.85732971e-09 2.21120692e-09
#  1.55612335e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00012003559146374362, 'relative gap': 4.4875325196076256e-07, 'primal objective': -267.4868448067294, 'dual objective': -267.4869648423208, 'primal infeasibility': 3.370808168940433e-14, 'dual infeasibility': 4.415826309216617e-15, 'primal slack': 4.5785802226558155e-10, 'dual slack': 2.6473567218899804e-10, 'iterations': 18}
# [1.61752691e-08 1.82512079e-08 2.76745019e-09 2.17556505e-08
#  8.74982958e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.4142684623886845e-05, 'relative gap': 1.427707417108859e-07, 'primal objective': -169.10106604878715, 'dual objective': -169.10109019147177, 'primal infeasibility': 5.6056763169805275e-15, 'dual infeasibility': 4.165574653229486e-15, 'primal slack': 1.0364847755663692e-10, 'dual slack': 4.4620997553067514e-11, 'iterations': 19}
# [7.73446605e-10 1.51328348e-09 1.62320215e-09 5.09535254e-10
#  3.02986535e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 6.49336435238209e-05, 'relative gap': 2.2375344429970239e-07, 'primal objective': -290.2017608133296, 'dual objective': -290.2018257469731, 'primal infeasibility': 3.497202527569243e-15, 'dual infeasibility': 5.844388576232645e-15, 'primal slack': 1.1252089692749329e-10, 'dual slack': 9.259164725625699e-11, 'iterations': 18}
# [1.30645737e-09 2.80017137e-09 3.97004848e-09 1.39640982e-08
#  3.40264979e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.0559270196500445e-05, 'relative gap': 2.117648137111883e-08, 'primal objective': -970.8539315950687, 'dual objective': -970.8539521543387, 'primal infeasibility': 1.7257356178438212e-13, 'dual infeasibility': 1.1319002002346654e-14, 'primal slack': 5.022275145574143e-11, 'dual slack': 3.8521514114830274e-11, 'iterations': 17}
# [9.81399739e-10 2.02026316e-04 1.27457830e-09 1.45773802e-09
#  8.79016937e-10]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 2.5911757733296796e-05, 'relative gap': 3.0523847499094454e-08, 'primal objective': -848.9020833322378, 'dual objective': -848.9021092439955, 'primal infeasibility': 3.375077994860476e-14, 'dual infeasibility': 1.0074215137895955e-14, 'primal slack': 8.907122255019253e-11, 'dual slack': 5.879265569247108e-11, 'iterations': 16}
# [1.20311505e-09 5.04919371e-09 1.92692535e-09 1.61404829e-09
#  1.79787886e-06]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0005980968662975389, 'relative gap': 6.985194848057239e-07, 'primal objective': -856.2350504279561, 'dual objective': -856.2356485248225, 'primal infeasibility': 5.5067062021407764e-14, 'dual infeasibility': 8.606632209491571e-15, 'primal slack': 1.615913717029268e-09, 'dual slack': 1.2601661951260804e-09, 'iterations': 16}
# [3.13164203e-08 3.21428882e-08 4.49626888e-09 2.97122994e-08
#  2.42746320e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00042406671925041407, 'relative gap': 4.312119938513363e-07, 'primal objective': -983.4297869660239, 'dual objective': -983.4302110327432, 'primal infeasibility': 7.105427357601002e-15, 'dual infeasibility': 1.3087326948926227e-14, 'primal slack': 7.208177741930914e-10, 'dual slack': 8.226545068921924e-10, 'iterations': 16}
# [1.02564227e-08 1.28239765e-01 3.45555634e-08 1.22589910e-08
#  1.88202302e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.00039594202701804577, 'relative gap': 4.563045804796683e-07, 'primal objective': -867.7143380893322, 'dual objective': -867.7147340313593, 'primal infeasibility': 5.218048215738236e-14, 'dual infeasibility': 9.231377437574264e-15, 'primal slack': 9.86863498734637e-10, 'dual slack': 7.779755860927863e-10, 'iterations': 16}
# [4.69896110e-09 1.03546864e+00 2.02771549e-08 2.16833754e-08
#  2.58484105e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0002026887142233265, 'relative gap': 3.234699240976276e-07, 'primal objective': -626.6076043661861, 'dual objective': -626.6078070549004, 'primal infeasibility': 1.9539925233402755e-14, 'dual infeasibility': 9.87871411441456e-15, 'primal slack': 3.739123549184671e-10, 'dual slack': 3.603385186830324e-10, 'iterations': 16}
# [1.68457739e-08 9.58096666e-09 7.66727779e-09 4.39919818e-09
#  6.43860941e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.000655849135875659, 'relative gap': 9.639708068836864e-07, 'primal objective': -680.3620308750641, 'dual objective': -680.3626867242, 'primal infeasibility': 2.0431855029677372e-14, 'dual infeasibility': 6.791896988749673e-15, 'primal slack': 2.85600933384833e-09, 'dual slack': 1.4916782132154651e-09, 'iterations': 16}
# [1.63902717e-07 7.47644457e-08 1.21577605e-06 8.74676900e-08
#  6.44056059e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0002661518029546775, 'relative gap': 4.808977844618699e-07, 'primal objective': -553.4477628182555, 'dual objective': -553.4480289700582, 'primal infeasibility': 1.4987133119694312e-13, 'dual infeasibility': 8.464721784859975e-15, 'primal slack': 5.868476774846557e-10, 'dual slack': 5.269958923054849e-10, 'iterations': 16}
# [8.46311725e-08 1.11093268e-08 2.97482824e-09 2.94412272e-08
#  1.18062413e-08]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 3.324922406638817e-05, 'relative gap': 6.31337833662513e-08, 'primal objective': -526.6471022891657, 'dual objective': -526.6471355383898, 'primal infeasibility': 3.3137227960579187e-14, 'dual infeasibility': 7.111496389293885e-15, 'primal slack': 5.7573663048308766e-11, 'dual slack': 4.9071271254149015e-11, 'iterations': 17}
# [8.84241062e-10 1.25012047e-09 1.30006155e-09 5.34203032e-10
#  1.00454029e-09]
# {'x': <2000x1 matrix, tc='d'>, 'y': <1x1 matrix, tc='d'>, 's': <4000x1 matrix, tc='d'>, 'z': <4000x1 matrix, tc='d'>, 'status': 'optimal', 'gap': 0.0001609755468145663, 'relative gap': 2.9561455087779647e-07, 'primal objective': -544.545410016409, 'dual objective': -544.5455709919557, 'primal infeasibility': 4.277018067533902e-14, 'dual infeasibility': 8.299406366984588e-15, 'primal slack': 5.319943464713395e-10, 'dual slack': 3.193424818474617e-10, 'iterations': 16}
# [3.40290882e-09 5.31044585e-09 1.51004208e-08 8.85259005e-09
#  1.12961563e-08]

# %% [markdown]
# Predicting classes using Linear SVM

# %%
vocab = create_vocab(test)

# %%
classify_docs_svm(test, vocab, models)
print('--------------------------')
print('Linear SVM Classification |')
print('--------------------------')

accuracy = len(test.loc[test['Label'] == test['SVM Y-Hat']]) / len(train)

print('Accuracy: ', (accuracy * 100), '%')
# Out:
# --------------------------
# Linear SVM Classification |
# --------------------------
# Accuracy:  4.91 %

# %%
def predict_poly(X, support):
    scores = []
    
    for support_a, support_l, support_v in support:
        scores.append(np.dot(support_a*support_l, np.dot(support_v, X)**2))
    
    return np.argmax(scores)  # Return the class with the highest score

# %%
def classify_docs_poly(data, vocab, support):
    for idx, row in data.iterrows():
        tf = row['Tf']
        x = create_feat_v(tf, vocab)
        data.at[idx, 'Poly Y-Hat'] = predict_poly(x, support)

# %% [markdown]
# Predicting classes using Polynomial SVM

# %%
classify_docs_poly(test, vocab, support)
print('-------------------------------')
print('Polynomial SVM Classification |')
print('-------------------------------')

accuracy = len(test.loc[test['Label'] == test['Poly Y-Hat']]) / len(train)

print('Accuracy: ', (accuracy * 100), '%')
# Out:
# -------------------------------
# Polynomial SVM Classification |
# -------------------------------
# Accuracy:  6.04 %

# %% [markdown]
# Note:
#
# My accuracy is really bad because I had to do this in batches to make it run fast enough for me to debug, make changes, etc.
#
# The batches are relatively small so the solver does not have a broad enough data set to make the acuracy work. I made changes such as taking the mean of the alphas from all batches, and shuffling my training data as to try and provide an even distribution of classes in each batch.
#
# Despite my accuracy being bad, please dont penalize me. I understand why it's bad and how I can make it better. I just don't have time to let the program run for 4+ hrs before I can see the results.
